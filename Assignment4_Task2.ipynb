# %% [markdown]
# <a href="https://colab.research.google.com/github/narekmi/MachineLearning/blob/main/Assignment4_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.datasets import load_iris

# %%
dataset = load_iris()
features = dataset.data

# %%
#iris_df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
#iris_df['Species'] = pd.Categorical.from_codes(dataset.target, dataset.target_names)
#print(iris_df.head())

# %%
inertia_values = []
silhouette_values = []
cluster_range = range(2, 10)

# %%
for num_clusters in cluster_range:
    model = KMeans(n_clusters=num_clusters, random_state=42)
    model.fit(features)

    inertia_values.append(model.inertia_)
    silhouette_values.append(silhouette_score(features, model.labels_))

# %%
# Elbow Plot
plt.figure(figsize=(8, 4))
plt.plot(cluster_range, inertia_values, "bx-")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.title("Elbow Plot: Inertia vs. Number of Clusters")
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.plot(cluster_range, silhouette_values, "bx-")
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Scores for K Values")
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
predicted_labels = kmeans.fit_predict(features)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(transformed_features[:, 0], transformed_features[:, 1], c=predicted_labels, cmap="viridis", edgecolor="k")
plt.title("Iris Dataset")
plt.show()
